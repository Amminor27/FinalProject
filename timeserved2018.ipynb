# %%
import pandas as pd   
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
releasedata2018 = pd.read_csv('/Users/debfleming/Desktop/timeserved.csv')

# %%
releasedata2018.head()
# Out:
#                      Unnamed: 0                 Unnamed: 1 Unnamed: 2  \
# 0                           NaN  Percent of total releases        NaN
# 1                  All offenses                        100          %
# 2                           NaN                       29.8          %
# 3                        Murder                        1.7        NaN
# 4  Non-negligent manslaughter/c                        0.4        NaN
#
#    Unnamed: 3 Time served in prison/a Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0         NaN               Median/b         NaN         NaN       Mean
# 1         NaN                     1.3       yrs.         NaN        2.7
# 2         NaN                     2.4       yrs.         NaN        4.8
# 3         NaN                    17.5        NaN         NaN       17.8
# 4         NaN                       7        NaN         NaN        8.2
#
#   Unnamed: 8
# 0        NaN
# 1       yrs.
# 2       yrs.
# 3        NaN
# 4        NaN

# %%
releasedata2018
# Out:
#                       Unnamed: 0                 Unnamed: 1 Unnamed: 2  \
# 0                            NaN  Percent of total releases        NaN
# 1                   All offenses                        100          %
# 2                            NaN                       29.8          %
# 3                         Murder                        1.7        NaN
# 4   Non-negligent manslaughter/c                        0.4        NaN
# 5         Negligent manslaughter                        0.8        NaN
# 6                         Rape                          1.5        NaN
# 7           Other sexual assault                        3.4        NaN
# 8                        Robbery                        7.4        NaN
# 9                        Assault                       11.6        NaN
# 10               Other violent/d                        2.3        NaN
# 11                           NaN                       25.7          %
# ...

# %%
releasedata2018.rename(columns = {'Unnamed: 0' : 'All Offenses', 'Unnamed: 1' : 'Percentage of total releases', 'Unnamed: 4' : 'Median Years Spent in Prison', 'Unnamed: 7' : 'Mean Years Spent in Prison'})
# Out:
#                     All Offenses Percentage of total releases Unnamed: 2  \
# 0                            NaN    Percent of total releases        NaN
# 1                   All offenses                          100          %
# 2                            NaN                         29.8          %
# 3                         Murder                          1.7        NaN
# 4   Non-negligent manslaughter/c                          0.4        NaN
# 5         Negligent manslaughter                          0.8        NaN
# 6                         Rape                            1.5        NaN
# 7           Other sexual assault                          3.4        NaN
# 8                        Robbery                          7.4        NaN
# 9                        Assault                         11.6        NaN
# 10               Other violent/d                          2.3        NaN
# 11                           NaN                         25.7          %
# ...
