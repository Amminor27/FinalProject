# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
recidivism = pd.read_csv('/Users/debfleming/Downloads/Recidivism.csv')
recidivism.head()
# Out:
#    Recidivism Reporting Year  Fiscal Year Admitted Region Code  \
# 0                       2013                  2010         NaN
# 1                       2013                  2010         NaN
# 2                       2013                  2010         NaN
# 3                       2013                  2010         NaN
# 4                       2013                  2010         NaN
#
#   Convicting Offense Classification Convicting Offense Type  \
# 0                          D Felony            Public Order
# 1               Serious Misdemeanor                Property
# 2               Serious Misdemeanor                Property
# 3               Serious Misdemeanor                    Drug
# 4            Aggravated Misdemeanor                    Drug
#
#   Convicting Offense Subtype                                 Race - Ethnicity  \
# 0                        OWI                                 White - Hispanic
# ...

# %%
dfrecidivism = pd.DataFrame(recidivism)

# %%
print(dfrecidivism)
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted Region Code  \
# 0                           2013                  2010         NaN
# 1                           2013                  2010         NaN
# 2                           2013                  2010         NaN
# 3                           2013                  2010         NaN
# 4                           2013                  2010         NaN
# ...                          ...                   ...         ...
# 96352                       2018                  2015         3JD
# 96353                       2018                  2015         2JD
# 96354                       2018                  2015         3JD
# 96355                       2018                  2015         2JD
# 96356                       2018                  2015         3JD
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# ...

# %%
display(dfrecidivism)
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted Region Code  \
# 0                           2013                  2010         NaN
# 1                           2013                  2010         NaN
# 2                           2013                  2010         NaN
# 3                           2013                  2010         NaN
# 4                           2013                  2010         NaN
# ...                          ...                   ...         ...
# 96352                       2018                  2015         3JD
# 96353                       2018                  2015         2JD
# 96354                       2018                  2015         3JD
# 96355                       2018                  2015         2JD
# 96356                       2018                  2015         3JD
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# ...

# %%
dfrecidivism.fillna(0)
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted Region Code  \
# 0                           2013                  2010           0
# 1                           2013                  2010           0
# 2                           2013                  2010           0
# 3                           2013                  2010           0
# 4                           2013                  2010           0
# ...                          ...                   ...         ...
# 96352                       2018                  2015         3JD
# 96353                       2018                  2015         2JD
# 96354                       2018                  2015         3JD
# 96355                       2018                  2015         2JD
# 96356                       2018                  2015         3JD
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# ...

# %%
display(dfrecidivism)
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted Region Code  \
# 0                           2013                  2010         NaN
# 1                           2013                  2010         NaN
# 2                           2013                  2010         NaN
# 3                           2013                  2010         NaN
# 4                           2013                  2010         NaN
# ...                          ...                   ...         ...
# 96352                       2018                  2015         3JD
# 96353                       2018                  2015         2JD
# 96354                       2018                  2015         3JD
# 96355                       2018                  2015         2JD
# 96356                       2018                  2015         3JD
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# ...

# %%
dfrecidivism.value_counts()
# Out:
# Recidivism Reporting Year  Fiscal Year Admitted  Region Code  Convicting Offense Classification  Convicting Offense Type  Convicting Offense Subtype  Race - Ethnicity      Sex   Level of Supervision  Recidivism - Prison Admission  Recidivism Type  New Conviction Offense Class  New Conviction Offense Type  New Conviction Offense SubType  Days to Recidivism  Part of Target Population
# 2017                       2014                  5JD          Aggravated Misdemeanor             Public Order             OWI                         White - Non-Hispanic  Male  Intensive             Yes                            New              Aggravated Misdemeanor        Public Order                 OWI                             654.0               Yes                          2
# ...

# %%
dfrecidivism.drop('Region Code', axis = 1, inplace = True)

# %%
display(dfrecidivism)
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted  \
# 0                           2013                  2010
# 1                           2013                  2010
# 2                           2013                  2010
# 3                           2013                  2010
# 4                           2013                  2010
# ...                          ...                   ...
# 96352                       2018                  2015
# 96353                       2018                  2015
# 96354                       2018                  2015
# 96355                       2018                  2015
# 96356                       2018                  2015
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# 1                   Serious Misdemeanor                Property
# 2                   Serious Misdemeanor                Property
# ...

# %%
dfrecidivism.drop('Part of Target Population', axis = 1, inplace = True)

# %%
display(dfrecidivism
        )
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted  \
# 0                           2013                  2010
# 1                           2013                  2010
# 2                           2013                  2010
# 3                           2013                  2010
# 4                           2013                  2010
# ...                          ...                   ...
# 96352                       2018                  2015
# 96353                       2018                  2015
# 96354                       2018                  2015
# 96355                       2018                  2015
# 96356                       2018                  2015
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# 1                   Serious Misdemeanor                Property
# 2                   Serious Misdemeanor                Property
# ...

# %%
dfrecidivism.drop('New Conviction Offense Class', axis = 1, inplace = True)

# %%
display(dfrecidivism)
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted  \
# 0                           2013                  2010
# 1                           2013                  2010
# 2                           2013                  2010
# 3                           2013                  2010
# 4                           2013                  2010
# ...                          ...                   ...
# 96352                       2018                  2015
# 96353                       2018                  2015
# 96354                       2018                  2015
# 96355                       2018                  2015
# 96356                       2018                  2015
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# 1                   Serious Misdemeanor                Property
# 2                   Serious Misdemeanor                Property
# ...

# %%
dfrecidivism.drop('New Conviction Offense Type', axis = 1, inplace = True)

# %%
dfrecidivism.drop('New Conviction Offense SubType', axis = 1, inplace = True)

# %%
display(dfrecidivism)
# Out:
#        Recidivism Reporting Year  Fiscal Year Admitted  \
# 0                           2013                  2010
# 1                           2013                  2010
# 2                           2013                  2010
# 3                           2013                  2010
# 4                           2013                  2010
# ...                          ...                   ...
# 96352                       2018                  2015
# 96353                       2018                  2015
# 96354                       2018                  2015
# 96355                       2018                  2015
# 96356                       2018                  2015
#
#       Convicting Offense Classification Convicting Offense Type  \
# 0                              D Felony            Public Order
# 1                   Serious Misdemeanor                Property
# 2                   Serious Misdemeanor                Property
# ...

# %%
dfrecidivism.value_counts('Days to Recidivism')
# Out:
# Days to Recidivism
# 245.0     33
# 329.0     32
# 476.0     31
# 336.0     30
# 357.0     29
#           ..
# 1055.0     1
# 20.0       1
# 1056.0     1
# 23.0       1
# 27.0       1
# Length: 1091, dtype: int64

# %%
dfrecidivism.value_counts('Recidivism - Prison Admission')
# Out:
# Recidivism - Prison Admission
# No     85431
# Yes    10926
# dtype: int64

# %%
dfrecidivism.value_counts('Recidivism Reporting Year')
# Out:
# Recidivism Reporting Year
# 2015    16286
# 2013    16226
# 2016    16049
# 2014    16048
# 2018    15910
# 2017    15838
# dtype: int64
